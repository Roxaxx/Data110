# %% [markdown]
# <a href="https://colab.research.google.com/github/Roxaxx/Data110/blob/main/Roxaxx_week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
print(plt. style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ##Style

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
plt.style.use('ggplot')

# %% [markdown]
# ##Basic lin Plot

# %%
##1
#Create plot of the quadric function
x = np.linspace(-2,4,100)
y = x**2-2*x+1
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##Multiple Lines

# %%
#plot Funcions
plt.plot(x, x**3, label='f(x) = x^3', color='green')
plt.plot(x, np.exp(x), label='g(x) =exp(x)', color='blue')
plt.plot(x, np.log(x),label='h(x) =log(x)', color='red') #for x>0
plt.legend()

#label the graph
plt.xlabel('x')
plt.ylabel('f(x), g(x), and h(x)')
plt.legend()
# Out:
# <ipython-input-92-ae7e208e1467>:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x),label='h(x) =log(x)', color='red') #for x>0
# <ipython-input-92-ae7e208e1467>:4: RuntimeWarning: invalid value encountered in log
#   plt.plot(x, np.log(x),label='h(x) =log(x)', color='red') #for x>0

# %% [markdown]
# ##Styling Lines

# %%
#select the range
x = np.linspace(-1,1,100)
#graph the plot with different color and line style
plt.plot(x, x**2, '-g', label='f(x) = x^2') # Green solid line
plt.plot(x, x**3, '--c', label='g(x) = x^3') # Cyan dashed line
plt.plot(x, x**4, '-.k', label='h(x) = x^4') # Black dash-dot line
plt.plot(x, x**5, ':r', label='i(x) = x^5') # Red dotted line
plt.legend()

#labels
plt.xlabel('x')
plt.ylabel('f(x), g(x), h(x), and i(x)')
plt.legend()

# %% [markdown]
# ##Axes Limits and Scaling

# %%
#plot the graph over the range [-10,10]

x=np.linspace(-10,10,100)

y = 1/(x**2+1)
plt.plot(x,y)

plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#Set appropriate custom x and y limits to showcase the function's behavior
x=np.linspace(-10,10,100)

y = 1/(x**2+1)
plt.plot(x,y)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(-5,5)
plt.ylim(0, 1.2)
# Out:
# (0.0, 1.2)

# %%
#first plot

x=np.linspace(-10,10,100)

y = 1/(x**2+1)

plt.plot(x, y, color = 'green')

plt.xlabel('x')
plt.ylabel('y')

#Create second plot same function withreversed x and y axes
x=np.linspace(-10,10,100)
plt.plot (y, x, color = 'red')

plt.axis('equal') # Setsequal scaling for both axes
plt.axis ('tight')
# Out:
# (-10.0, 10.0, -10.0, 10.0)

# %% [markdown]
# ###Labels and Legends

# %%
#rqnge (x>=0)
x = np.linspace(0, 10, 400)
y1 = x
y2 = x**(1/3)

plt.plot(x, y1, label='x')
plt.plot(x, y2, label='x^(1/3)')
plt.title('Fuctions with Labels and Legends')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ###Basic Scatter Plot

# %%
#Generate 50 random points
x =np.random.rand(50)
y =np.random.rand(50)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# #Create the same scatter plot using plt.scatter()

# %%
plt.scatter(x, y, color = 'green')

# %% [markdown]
# ##Customizing Scatter Plots

# %%
#Generate data for the function f(X)=xsin(x), over the range [0,4pi]
x=np.linspace(0,4*np.pi,100)
y=x*np.sin(x)

#Generate data for the function f(X)=xsin(x), over the range [0,4pi]
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,4*np.pi,100)
y=x*np.sin(x)

#Create the scatter plot
plt.plot(x,y, color = 'red', linewidth = 2, label ='line plot')
plt.scatter(x,y,s = 70, color = 'black', label='scatter plot', facecolors= 'pink', edgecolor= 'black', linewidths=2)

#labels
plt.title('Scatter Plot of f(x)= a *sin(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ##Combine Plot

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
f_x = x * np.cos (x)
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
f_x = x * np.cos(x)

plt.plot(x, f_x, label='f(x)=x cos (x)', color='blue')
scatter_x = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
plt.scatter(scatter_x, scatter_x * np.cos(scatter_x), color='red', label='scatter points')
plt.legend()
plt.title('Combine Line and Scatter Plot')
plt.show()

# %% [markdown]
# ##Custom Plot with Alternative Style

# %%
plt.style.use('seaborn-v0_8-whitegrid')

x = np.linspace (-10,10,200)
f_x = np.tan (x)
g_x = x *np.exp(-x**2)
h_x =np.sin (x) /x

plt.plot(x,f_x, label="tan (x)", linestyle='--')
plt.plot(x, g_x, label= "x * exp(-x 2)", linestyle='-.')
plt.plot(x, h_x, label='sin (x)/x', linestyle=':')

plt.title ('Custom Plot with Aternatives Style')
plt.legend()
plt.show()

# %% [markdown]
# ##Style Comparison

# %%
print(plt.style.available)

#plot the graph
plt.plot(x, x**2 -2*x + 1)

#Style
plt.style.use('seaborn-v0_8-whitegrid')

#xlabel and ylabel
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('Style - seaborn-whitegrid')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# Text(0.5, 1.0, 'Style - seaborn-whitegrid')

# %%
#plot the graph
plt.plot(x, x**2 -2*x + 1)
#plot the graph
plt.plot(x, x**2 -2*x + 1)

#Style
plt.style.use('dark_background')

#xlabel and ylabel
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('Style - black_background')
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('Style - black_background')
# Out:
# Text(0.5, 1.0, 'Style - black_background')

# %%
#plot the graph
plt.plot(x, x**2 -2*x + 1)

#Style
plt.style.use('classic')

#xlabel and ylabel
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('Style - classic')
# Out:
# Text(0.5, 1.0, 'Style - classic')
